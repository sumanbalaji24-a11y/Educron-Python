# %% [markdown]
# ## Operators in python

# %% [markdown]
# ### Assignment Operator

# %%
a =10;
print(a)
# Out:
# 10

# %% [markdown]
# ### Arithmatic Operators

# %%
a = 10;
b= 20;
sum = a+b;
mul = a*b;
division = a/b;
mod= a%b;
expo = a**2;

print("sum",sum);
print("mul",mul);
print("div",division);
print("mod",mod)
print("expo",expo)
# Out:
# sum 30
# mul 200
# div 0.5
# mod 10
# expo 100

# %% [markdown]
# ### Conditional operators

# %%
# ==
# !=
# >
# <
# >=
# <=

# %% [markdown]
# ### Logical operators

# %%
# and
# or

# %% [markdown]
# ### Identity operators

# %%
# is 
# is no 
a = ["suman","kiran"];
b = a;
print(a is b);
b[0] = "mokshith";
print(a is  b);
print(a,b)  ## if a and b are pointing to same reference changing b should also change a right ?
# Out:
# True
# True
# ['mokshith', 'kiran'] ['mokshith', 'kiran']

# %% [markdown]
# ## Logical operators
