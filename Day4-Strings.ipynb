# %% [markdown]
# # Strings

# %%
text ="test"
text1='dummy'
text2="""
hello how are you
"""

# %%
print(text)
print(text1)
print(text2)
type(text)
# Out:
# test
# dummy
#
# hello how are you
# str

# %% [markdown]
# ## f-string

# %%
a =10;
b=20;
print(f"sum of a and b is {a+b}")
# Out:
# sum of a and b is 30

# %% [markdown]
# * for repeating characters

# %%
v= "suman " * 3;
print(v)
# Out:
# suman suman suman
