# %% [markdown]
# ## Boolean
# 1. Represents one of two truth always: True or False
# 2. True Corresponds to 1
# 3. False Corressponds to 0
# 4. Comparision Operators and logical operators awalys gives us a boolean value
# 5. and and or operator
# 6. not

# %%
isActive = True
isVerified = False
print(isActive and isVerified)
print(isVerified or isActive)
print(not not isActive)
# Out:
# False
# True
# True

# %% [markdown]
# ## Conditional Statements
# 1. If
# 2. Else If
# 3. if else if else
# 4. Nested Conditions

# %%
## If statement
age =int(input("Enter your age"))
if age>=18:
    print("you are an adult")
else:
    print("you are not an adult yet")
# Out:
# you are an adult

# %%
password = input("enter your passwrod")
if(len(password)>=8):
    print("Valid password")
else:
    print("Passwors Must contain 8 or more characters ")
# Out:
# Passwors Must be 8 characters or more
